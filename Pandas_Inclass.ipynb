# %% [markdown]
# ### Agenda

# %% [markdown]
# <b>
# <br>1.Understanding the usage of Data and its Business Application.
# <br>2.Pandas data structures like Series,DataFrame,Panel
# <br>3.What is Data Analysis?
# <br>4.Importing and Exporting Data in Python
# <br>5.Dataframe operations

# %% [markdown]
# ## Pandas

# %% [markdown]
# <b>pandas is “a software library written for the Python programming language for data manipulation and analysis.”

# %% [markdown]
# <html>
# <b>Key Features of Pandas</b>
#
# ><br>Fast and efficient DataFrame object with default and customized indexing.
# ><br>Tools for loading data into in-memory data objects from different file formats.
# ><br>Data alignment and integrated handling of missing data.
# ><br>Reshaping and pivoting of date sets.
# ><br>Label-based slicing, indexing and subsetting of large data sets.
# ><br>Columns from a data structure can be deleted or inserted.
# ><br>Group by data for aggregation and transformations.
# ><br>High performance merging and joining of data.

# %%
import pandas as pd
#li = [10,20,32,43,23,89,98,15]
li = [2,'hello','hello']
s1 = pd.Series(li)

data = pd.DataFrame(s1,columns = ['Num1'])
data.describe(include = 'all')
# Out:
#          Num1
# count       3
# unique      2
# top     hello
# freq        2

# %% [markdown]
# ### Series

# %%
import pandas as pd
seri = [1,2,3,4]
d = pd.DataFrame(seri)

# %%
df = pd.Series({'name':'akon'})
df
# Out:
# name    akon
# dtype: object

# %% [markdown]
# ### DataFrame

# %% [markdown]
# ### Import Data

# %% [markdown]
# Two important properties:
# 1.Format like csv,xlsx,json...
# 2.File path of the Dataset.... Local/url

# %%
import pandas as pd
data = pd.read_csv('Auto.csv')
data
#data.set_index('symboling')
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2                NaN         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1                NaN         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0                NaN         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# 13           0              188.0          bmw       gas        std
# 14           1                NaN          bmw       gas        std
# 15           0                NaN          bmw       gas        std
# 16           0                NaN          bmw       gas        std
# 17           0                NaN          bmw       gas        std
# 18           2              121.0    chevrolet       gas        std
# 19           1               98.0    chevrolet       gas        std
# 20           0               81.0    chevrolet       gas        std
# 21           1              118.0        dodge       gas        std
# 22           1              118.0        dodge       gas        std
# 23           1              118.0        dodge       gas      turbo
# 24           1              148.0        dodge       gas        std
# 25           1              148.0        dodge       gas        std
# 26           1              148.0        dodge       gas        std
# 27           1              148.0        dodge       gas      turbo
# 28          -1              110.0        dodge       gas        std
# 29           3              145.0        dodge       gas      turbo
# ..         ...                ...          ...       ...        ...
# 175         -1               65.0       toyota       gas        std
# 176         -1               65.0       toyota       gas        std
# 177         -1               65.0       toyota       gas        std
# 178          3              197.0       toyota       gas        std
# 179          3              197.0       toyota       gas        std
# 180         -1               90.0       toyota       gas        std
# 181         -1                NaN       toyota       gas        std
# 182          2              122.0   volkswagen    diesel        std
# 183          2              122.0   volkswagen       gas        std
# 184          2               94.0   volkswagen    diesel        std
# 185          2               94.0   volkswagen       gas        std
# 186          2               94.0   volkswagen       gas        std
# 187          2               94.0   volkswagen    diesel      turbo
# 188          2               94.0   volkswagen       gas        std
# 189          3                NaN   volkswagen       gas        std
# 190          3              256.0   volkswagen       gas        std
# 191          0                NaN   volkswagen       gas        std
# 192          0                NaN   volkswagen    diesel      turbo
# 193          0                NaN   volkswagen       gas        std
# 194         -2              103.0        volvo       gas        std
# 195         -1               74.0        volvo       gas        std
# 196         -2              103.0        volvo       gas        std
# 197         -1               74.0        volvo       gas        std
# 198         -2              103.0        volvo       gas      turbo
# 199         -1               74.0        volvo       gas      turbo
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# 1            two  convertible          rwd           front        88.6
# 2            two    hatchback          rwd           front        94.5
# 3           four        sedan          fwd           front        99.8
# 4           four        sedan          4wd           front        99.4
# 5            two        sedan          fwd           front        99.8
# 6           four        sedan          fwd           front       105.8
# 7           four        wagon          fwd           front       105.8
# 8           four        sedan          fwd           front       105.8
# 9            two    hatchback          4wd           front        99.5
# 10           two        sedan          rwd           front       101.2
# 11          four        sedan          rwd           front       101.2
# 12           two        sedan          rwd           front       101.2
# 13          four        sedan          rwd           front       101.2
# 14          four        sedan          rwd           front       103.5
# 15          four        sedan          rwd           front       103.5
# 16           two        sedan          rwd           front       103.5
# 17          four        sedan          rwd           front       110.0
# 18           two    hatchback          fwd           front        88.4
# 19           two    hatchback          fwd           front        94.5
# 20          four        sedan          fwd           front        94.5
# 21           two    hatchback          fwd           front        93.7
# 22           two    hatchback          fwd           front        93.7
# 23           two    hatchback          fwd           front        93.7
# 24          four    hatchback          fwd           front        93.7
# 25          four        sedan          fwd           front        93.7
# 26          four        sedan          fwd           front        93.7
# 27           NaN        sedan          fwd           front        93.7
# 28          four        wagon          fwd           front       103.3
# 29           two    hatchback          fwd           front        95.9
# ..           ...          ...          ...             ...         ...
# 175         four    hatchback          fwd           front       102.4
# 176         four        sedan          fwd           front       102.4
# 177         four    hatchback          fwd           front       102.4
# 178          two    hatchback          rwd           front       102.9
# 179          two    hatchback          rwd           front       102.9
# 180         four        sedan          rwd           front       104.5
# 181         four        wagon          rwd           front       104.5
# 182          two        sedan          fwd           front        97.3
# 183          two        sedan          fwd           front        97.3
# 184         four        sedan          fwd           front        97.3
# 185         four        sedan          fwd           front        97.3
# 186         four        sedan          fwd           front        97.3
# 187         four        sedan          fwd           front        97.3
# 188         four        sedan          fwd           front        97.3
# 189          two  convertible          fwd           front        94.5
# 190          two    hatchback          fwd           front        94.5
# 191         four        sedan          fwd           front       100.4
# 192         four        sedan          fwd           front       100.4
# 193         four        wagon          fwd           front       100.4
# 194         four        sedan          rwd           front       104.3
# 195         four        wagon          rwd           front       104.3
# 196         four        sedan          rwd           front       104.3
# 197         four        wagon          rwd           front       104.3
# 198         four        sedan          rwd           front       104.3
# 199         four        wagon          rwd           front       104.3
# 200         four        sedan          rwd           front       109.1
# 201         four        sedan          rwd           front       109.1
# 202         four        sedan          rwd           front       109.1
# 203         four        sedan          rwd           front       109.1
# 204         four        sedan          rwd           front       109.1
#
#       ...     engine-size  fuel-system  bore  stroke compression-ratio  \
# 0     ...             130         mpfi  3.47    2.68              9.00
# 1     ...             130         mpfi  3.47    2.68              9.00
# 2     ...             152         mpfi  2.68    3.47              9.00
# 3     ...             109         mpfi  3.19    3.40             10.00
# 4     ...             136         mpfi  3.19    3.40              8.00
# 5     ...             136         mpfi  3.19    3.40              8.50
# 6     ...             136         mpfi  3.19    3.40              8.50
# 7     ...             136         mpfi  3.19    3.40              8.50
# 8     ...             131         mpfi  3.13    3.40              8.30
# 9     ...             131         mpfi  3.13    3.40              7.00
# 10    ...             108         mpfi  3.50    2.80              8.80
# 11    ...             108         mpfi  3.50    2.80              8.80
# 12    ...             164         mpfi  3.31    3.19              9.00
# 13    ...             164         mpfi  3.31    3.19              9.00
# 14    ...             164         mpfi  3.31    3.19              9.00
# 15    ...             209         mpfi  3.62    3.39              8.00
# 16    ...             209         mpfi  3.62    3.39              8.00
# 17    ...             209         mpfi  3.62    3.39              8.00
# 18    ...              61         2bbl  2.91    3.03              9.50
# 19    ...              90         2bbl  3.03    3.11              9.60
# 20    ...              90         2bbl  3.03    3.11              9.60
# 21    ...              90         2bbl  2.97    3.23              9.41
# 22    ...              90         2bbl  2.97    3.23              9.40
# 23    ...              98         mpfi  3.03    3.39              7.60
# 24    ...              90         2bbl  2.97    3.23              9.40
# 25    ...              90         2bbl  2.97    3.23              9.40
# 26    ...              90         2bbl  2.97    3.23              9.40
# 27    ...              98         mpfi  3.03    3.39              7.60
# 28    ...             122         2bbl  3.34    3.46              8.50
# 29    ...             156          mfi  3.60    3.90              7.00
# ..    ...             ...          ...   ...     ...               ...
# 175   ...             122         mpfi  3.31    3.54              8.70
# 176   ...             122         mpfi  3.31    3.54              8.70
# 177   ...             122         mpfi  3.31    3.54              8.70
# 178   ...             171         mpfi  3.27    3.35              9.30
# 179   ...             171         mpfi  3.27    3.35              9.30
# 180   ...             171         mpfi  3.27    3.35              9.20
# 181   ...             161         mpfi  3.27    3.35              9.20
# 182   ...              97          idi  3.01    3.40             23.00
# 183   ...             109         mpfi  3.19    3.40              9.00
# 184   ...              97          idi  3.01    3.40             23.00
# 185   ...             109         mpfi  3.19    3.40              9.00
# 186   ...             109         mpfi  3.19    3.40              9.00
# 187   ...              97          idi  3.01    3.40             23.00
# 188   ...             109         mpfi  3.19    3.40             10.00
# 189   ...             109         mpfi  3.19    3.40              8.50
# 190   ...             109         mpfi  3.19    3.40              8.50
# 191   ...             136         mpfi  3.19    3.40              8.50
# 192   ...              97          idi  3.01    3.40             23.00
# 193   ...             109         mpfi  3.19    3.40              9.00
# 194   ...             141         mpfi  3.78    3.15              9.50
# 195   ...             141         mpfi  3.78    3.15              9.50
# 196   ...             141         mpfi  3.78    3.15              9.50
# 197   ...             141         mpfi  3.78    3.15              9.50
# 198   ...             130         mpfi  3.62    3.15              7.50
# 199   ...             130         mpfi  3.62    3.15              7.50
# 200   ...             141         mpfi  3.78    3.15              9.50
# 201   ...             141         mpfi  3.78    3.15              8.70
# 202   ...             173         mpfi  3.58    2.87              8.80
# 203   ...             145          idi  3.01    3.40             23.00
# 204   ...             141         mpfi  3.78    3.15              9.50
#
#     horsepower  peak-rpm city-mpg  highway-mpg    price
# 0        111.0    5000.0       21           27  13495.0
# 1        111.0    5000.0       21           27  16500.0
# 2        154.0    5000.0       19           26  16500.0
# 3        102.0    5500.0       24           30  13950.0
# 4        115.0    5500.0       18           22  17450.0
# 5        110.0    5500.0       19           25  15250.0
# 6        110.0    5500.0       19           25  17710.0
# 7        110.0    5500.0       19           25  18920.0
# 8        140.0    5500.0       17           20  23875.0
# 9        160.0    5500.0       16           22      NaN
# 10       101.0    5800.0       23           29  16430.0
# 11       101.0    5800.0       23           29  16925.0
# 12       121.0    4250.0       21           28  20970.0
# 13       121.0    4250.0       21           28  21105.0
# 14       121.0    4250.0       20           25  24565.0
# 15       182.0    5400.0       16           22  30760.0
# 16       182.0    5400.0       16           22  41315.0
# 17       182.0    5400.0       15           20  36880.0
# 18        48.0    5100.0       47           53   5151.0
# 19        70.0    5400.0       38           43   6295.0
# 20        70.0    5400.0       38           43   6575.0
# 21        68.0    5500.0       37           41   5572.0
# 22        68.0    5500.0       31           38   6377.0
# 23       102.0    5500.0       24           30   7957.0
# 24        68.0    5500.0       31           38   6229.0
# 25        68.0    5500.0       31           38   6692.0
# 26        68.0    5500.0       31           38   7609.0
# 27       102.0    5500.0       24           30   8558.0
# 28        88.0    5000.0       24           30   8921.0
# 29       145.0    5000.0       19           24  12964.0
# ..         ...       ...      ...          ...      ...
# 175       92.0    4200.0       27           32   9988.0
# 176       92.0    4200.0       27           32  10898.0
# 177       92.0    4200.0       27           32  11248.0
# 178      161.0    5200.0       20           24  16558.0
# 179      161.0    5200.0       19           24  15998.0
# 180      156.0    5200.0       20           24  15690.0
# 181      156.0    5200.0       19           24  15750.0
# 182       52.0    4800.0       37           46   7775.0
# 183       85.0    5250.0       27           34   7975.0
# 184       52.0    4800.0       37           46   7995.0
# 185       85.0    5250.0       27           34   8195.0
# 186       85.0    5250.0       27           34   8495.0
# 187       68.0    4500.0       37           42   9495.0
# 188      100.0    5500.0       26           32   9995.0
# 189       90.0    5500.0       24           29  11595.0
# 190       90.0    5500.0       24           29   9980.0
# 191      110.0    5500.0       19           24  13295.0
# 192       68.0    4500.0       33           38  13845.0
# 193       88.0    5500.0       25           31  12290.0
# 194      114.0    5400.0       23           28  12940.0
# 195      114.0    5400.0       23           28  13415.0
# 196      114.0    5400.0       24           28  15985.0
# 197      114.0    5400.0       24           28  16515.0
# 198      162.0    5100.0       17           22  18420.0
# 199      162.0    5100.0       17           22  18950.0
# 200      114.0    5400.0       23           28  16845.0
# 201      160.0    5300.0       19           25  19045.0
# 202      134.0    5500.0       18           23  21485.0
# 203      106.0    4800.0       26           27  22470.0
# 204      114.0    5400.0       19           25  22625.0
#
# [205 rows x 26 columns]

# %% [markdown]
# ## Acessing Pandas Series

# %%
data.make
data['make']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
# 5             audi
# 6             audi
# 7             audi
# 8             audi
# 9             audi
# 10             bmw
# 11             bmw
# 12             bmw
# 13             bmw
# 14             bmw
# 15             bmw
# 16             bmw
# 17             bmw
# 18       chevrolet
# 19       chevrolet
# 20       chevrolet
# 21           dodge
# 22           dodge
# 23           dodge
# 24           dodge
# 25           dodge
# 26           dodge
# 27           dodge
# 28           dodge
# 29           dodge
#           ...
# 175         toyota
# 176         toyota
# 177         toyota
# 178         toyota
# 179         toyota
# 180         toyota
# 181         toyota
# 182     volkswagen
# 183     volkswagen
# 184     volkswagen
# 185     volkswagen
# 186     volkswagen
# 187     volkswagen
# 188     volkswagen
# 189     volkswagen
# 190     volkswagen
# 191     volkswagen
# 192     volkswagen
# 193     volkswagen
# 194          volvo
# 195          volvo
# 196          volvo
# 197          volvo
# 198          volvo
# 199          volvo
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: make, Length: 205, dtype: object

# %%
#check the data
#data.head(10)
data.tail(10)
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 195         -1               74.0  volvo       gas        std         four
# 196         -2              103.0  volvo       gas        std         four
# 197         -1               74.0  volvo       gas        std         four
# 198         -2              103.0  volvo       gas      turbo         four
# 199         -1               74.0  volvo       gas      turbo         four
# 200         -1               95.0  volvo       gas        std         four
# 201         -1               95.0  volvo       gas      turbo         four
# 202         -1               95.0  volvo       gas        std         four
# 203         -1               95.0  volvo    diesel      turbo         four
# 204         -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base   ...     engine-size  \
# 195      wagon          rwd           front       104.3   ...             141
# 196      sedan          rwd           front       104.3   ...             141
# 197      wagon          rwd           front       104.3   ...             141
# 198      sedan          rwd           front       104.3   ...             130
# 199      wagon          rwd           front       104.3   ...             130
# 200      sedan          rwd           front       109.1   ...             141
# 201      sedan          rwd           front       109.1   ...             141
# 202      sedan          rwd           front       109.1   ...             173
# 203      sedan          rwd           front       109.1   ...             145
# 204      sedan          rwd           front       109.1   ...             141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 195         mpfi  3.78    3.15               9.5      114.0    5400.0
# 196         mpfi  3.78    3.15               9.5      114.0    5400.0
# 197         mpfi  3.78    3.15               9.5      114.0    5400.0
# 198         mpfi  3.62    3.15               7.5      162.0    5100.0
# 199         mpfi  3.62    3.15               7.5      162.0    5100.0
# 200         mpfi  3.78    3.15               9.5      114.0    5400.0
# 201         mpfi  3.78    3.15               8.7      160.0    5300.0
# 202         mpfi  3.58    2.87               8.8      134.0    5500.0
# 203          idi  3.01    3.40              23.0      106.0    4800.0
# 204         mpfi  3.78    3.15               9.5      114.0    5400.0
#
#     city-mpg  highway-mpg    price
# 195       23           28  13415.0
# 196       24           28  15985.0
# 197       24           28  16515.0
# 198       17           22  18420.0
# 199       17           22  18950.0
# 200       23           28  16845.0
# 201       19           25  19045.0
# 202       18           23  21485.0
# 203       26           27  22470.0
# 204       19           25  22625.0
#
# [10 rows x 26 columns]

# %% [markdown]
# ### Panel
# Pandas panel can hold multiple data structures

# %%
# importing pandas module   
import pandas as pd   
import numpy as np  
    
df1 = pd.DataFrame({'a': ['N1', 'N2', 'N3', 'N4', 'N5'],   
                    'b': [11, 1.025, 333, 114.48, 1333]}) 
print(df1)
                        
dat = {'item1':df1, 'item2':df1}
# creating Panel   
panel = pd.Panel.from_dict(dat, orient ='minor') 
panel
# Out:
#     a         b
# 0  N1    11.000
# 1  N2     1.025
# 2  N3   333.000
# 3  N4   114.480
# 4  N5  1333.000
# C:\Users\1513353\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   # This is added back by InteractiveShellApp.init_path()
# <class 'pandas.core.panel.Panel'>
# Dimensions: 2 (items) x 5 (major_axis) x 2 (minor_axis)
# Items axis: a to b
# Major_axis axis: 0 to 4
# Minor_axis axis: item1 to item2

# %%
import pandas as pd
#pd.read_json('Test.json')
json_d =pd.read_json(r'C:\Users\1513353\Test.json')
json_d
# Out:
#                                             Avengers
# 0  {'Name': 'Tony stark', 'also known as': 'Iron ...
# 1  {'Name': 'Peter parker', 'also known as': 'Spi...

# %% [markdown]
# ### Export Data

# %%
data.head().to_csv('sample.csv',index = False)

# %%
json_d.to_json('test.json')

# %% [markdown]
# ## Data Understanding

# %%
#Data types
#Data Distribution
#data.dtypes
#data['symboling'].dtype
data.describe()
#data.describe(include = 'all')
#data.shape
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2145.000000    97.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.290000
# 75%     55.500000  2935.000000   141.000000    3.590000    3.410000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         205.000000  203.000000   203.000000  205.000000   205.000000
# mean           10.142537  104.256158  5125.369458   25.219512    30.751220
# std             3.972040   39.714369   479.334560    6.542142     6.886443
# min             7.000000   48.000000  4150.000000   13.000000    16.000000
# 25%             8.600000   70.000000  4800.000000   19.000000    25.000000
# 50%             9.000000   95.000000  5200.000000   24.000000    30.000000
# 75%             9.400000  116.000000  5500.000000   30.000000    34.000000
# max            23.000000  288.000000  6600.000000   49.000000    54.000000
#
#               price
# count    201.000000
# mean   13207.129353
# std     7947.066342
# min     5118.000000
# 25%     7775.000000
# 50%    10295.000000
# 75%    16500.000000
# max    45400.000000

# %% [markdown]
# ## Handling Missing Values
#
# <br>When nodata value is stored for a feature for a particular observation, we say this
# feature has a “missing value”.
# <br>Usually “missing value: in dataset” appears as “?”, “N/A”, 0 or just a blank cell(NaN).

# %% [markdown]
# #### Missings Values

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
data['normalized-losses'].isnull().value_counts()
#data['normalized-losses'].isna()
# Out:
# False    164
# True      41
# Name: normalized-losses, dtype: int64

# %%
df = data.dropna(subset = ['normalized-losses'])

# %%
df['normalized-losses'].isna().unique()
# Out:
# array([False])

# %%
## inplace= True helps in direcetly replace in a actual dataset
data

# %%
## calculating Mean and Filling In place of NaN
mean = data['normalized-losses'].mean()
mean
# Out:
# 122.0

# %%
import numpy as np
data['normalized-losses'].replace(np.nan,mean)
# Out:
# 0      122.0
# 1      122.0
# 2      122.0
# 3      164.0
# 4      164.0
# 5      122.0
# 6      158.0
# 7      122.0
# 8      158.0
# 9      122.0
# 10     192.0
# 11     192.0
# 12     188.0
# 13     188.0
# 14     122.0
# 15     122.0
# 16     122.0
# 17     122.0
# 18     121.0
# 19      98.0
# 20      81.0
# 21     118.0
# 22     118.0
# 23     118.0
# 24     148.0
# 25     148.0
# 26     148.0
# 27     148.0
# 28     110.0
# 29     145.0
#        ...
# 175     65.0
# 176     65.0
# 177     65.0
# 178    197.0
# 179    197.0
# 180     90.0
# 181    122.0
# 182    122.0
# 183    122.0
# 184     94.0
# 185     94.0
# 186     94.0
# 187     94.0
# 188     94.0
# 189    122.0
# 190    256.0
# 191    122.0
# 192    122.0
# 193    122.0
# 194    103.0
# 195     74.0
# 196    103.0
# 197     74.0
# 198    103.0
# 199     74.0
# 200     95.0
# 201     95.0
# 202     95.0
# 203     95.0
# 204     95.0
# Name: normalized-losses, Length: 205, dtype: float64

# %%
flights = pd.read_csv('flights.csv')
flights['passengers'].isna().unique()
flights.replace({'?':np.nan},inplace = True)
flights.tail()
flights['passengers'].isna().any()
flights.fillna(axis = 0,method = 'ffill',inplace = True)
flights.tail()
# Out:
#      year      month passengers
# 140  1960  September        508
# 141  1960    October        461
# 142  1960   November        390
# 143  1960   December        432
# 144  1960       June        432

# %% [markdown]
# ## Operatipon On dataframe

# %%
data['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
import numpy as np
s = pd.Series(["a", "b", "c"])
s.loc[1] = np.nan
s
# Out:
# 0      a
# 1    NaN
# 2      c
# dtype: object

# %%
s.fillna(0)
# Out:
# 0    a
# 1    0
# 2    c
# dtype: object

# %% [markdown]
# #### Iterating/Filtering data frame

# %%
data.loc[:,['make','price']]
# Out:
#             make    price
# 0    alfa-romero  13495.0
# 1    alfa-romero  16500.0
# 2    alfa-romero  16500.0
# 3           audi  13950.0
# 4           audi  17450.0
# 5           audi  15250.0
# 6           audi  17710.0
# 7           audi  18920.0
# 8           audi  23875.0
# 9           audi      NaN
# 10           bmw  16430.0
# 11           bmw  16925.0
# 12           bmw  20970.0
# 13           bmw  21105.0
# 14           bmw  24565.0
# 15           bmw  30760.0
# 16           bmw  41315.0
# 17           bmw  36880.0
# 18     chevrolet   5151.0
# 19     chevrolet   6295.0
# 20     chevrolet   6575.0
# 21         dodge   5572.0
# 22         dodge   6377.0
# 23         dodge   7957.0
# 24         dodge   6229.0
# 25         dodge   6692.0
# 26         dodge   7609.0
# 27         dodge   8558.0
# 28         dodge   8921.0
# 29         dodge  12964.0
# ..           ...      ...
# 175       toyota   9988.0
# 176       toyota  10898.0
# 177       toyota  11248.0
# 178       toyota  16558.0
# 179       toyota  15998.0
# 180       toyota  15690.0
# 181       toyota  15750.0
# 182   volkswagen   7775.0
# 183   volkswagen   7975.0
# 184   volkswagen   7995.0
# 185   volkswagen   8195.0
# 186   volkswagen   8495.0
# 187   volkswagen   9495.0
# 188   volkswagen   9995.0
# 189   volkswagen  11595.0
# 190   volkswagen   9980.0
# 191   volkswagen  13295.0
# 192   volkswagen  13845.0
# 193   volkswagen  12290.0
# 194        volvo  12940.0
# 195        volvo  13415.0
# 196        volvo  15985.0
# 197        volvo  16515.0
# 198        volvo  18420.0
# 199        volvo  18950.0
# 200        volvo  16845.0
# 201        volvo  19045.0
# 202        volvo  21485.0
# 203        volvo  22470.0
# 204        volvo  22625.0
#
# [205 rows x 2 columns]

# %%
#data.iloc[1:5]
data.loc[1:5,'make']
#data.loc[:,['make','price']].head(10)
#data.iloc[:,1:4].head(10)
# Out:
# 1    alfa-romero
# 2    alfa-romero
# 3           audi
# 4           audi
# 5           audi
# Name: make, dtype: object

# %% [markdown]
# #### Filtering data using Condition

# %%
data['price']
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
# 6      17710.0
# 7      18920.0
# 8      23875.0
# 9          NaN
# 10     16430.0
# 11     16925.0
# 12     20970.0
# 13     21105.0
# 14     24565.0
# 15     30760.0
# 16     41315.0
# 17     36880.0
# 18      5151.0
# 19      6295.0
# 20      6575.0
# 21      5572.0
# 22      6377.0
# 23      7957.0
# 24      6229.0
# 25      6692.0
# 26      7609.0
# 27      8558.0
# 28      8921.0
# 29     12964.0
#         ...
# 175     9988.0
# 176    10898.0
# 177    11248.0
# 178    16558.0
# 179    15998.0
# 180    15690.0
# 181    15750.0
# 182     7775.0
# 183     7975.0
# 184     7995.0
# 185     8195.0
# 186     8495.0
# 187     9495.0
# 188     9995.0
# 189    11595.0
# 190     9980.0
# 191    13295.0
# 192    13845.0
# 193    12290.0
# 194    12940.0
# 195    13415.0
# 196    15985.0
# 197    16515.0
# 198    18420.0
# 199    18950.0
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
data[data['price'] > 20000].head(10)
data[(data['price']> 20000) & (data['make'] == 'volvo')]
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 202         -1               95.0  volvo       gas        std         four
# 203         -1               95.0  volvo    diesel      turbo         four
# 204         -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base   ...     engine-size  \
# 202      sedan          rwd           front       109.1   ...             173
# 203      sedan          rwd           front       109.1   ...             145
# 204      sedan          rwd           front       109.1   ...             141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 202         mpfi  3.58    2.87               8.8      134.0    5500.0
# 203          idi  3.01    3.40              23.0      106.0    4800.0
# 204         mpfi  3.78    3.15               9.5      114.0    5400.0
#
#     city-mpg  highway-mpg    price
# 202       18           23  21485.0
# 203       26           27  22470.0
# 204       19           25  22625.0
#
# [3 rows x 26 columns]

# %%
data.loc[data['make'].str.startswith('au'),['make','num-of-doors','price']].head(10)
# Out:
#    make num-of-doors    price
# 3  audi         four  13950.0
# 4  audi         four  17450.0
# 5  audi          two  15250.0
# 6  audi         four  17710.0
# 7  audi         four  18920.0
# 8  audi         four  23875.0
# 9  audi          two      NaN

# %%
data.sort_values(by = 'price',ascending = False).head(10)
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 74           1                NaN  mercedes-benz       gas        std
# 16           0                NaN            bmw       gas        std
# 73           0                NaN  mercedes-benz       gas        std
# 128          3                NaN        porsche       gas        std
# 17           0                NaN            bmw       gas        std
# 49           0                NaN         jaguar       gas        std
# 48           0                NaN         jaguar       gas        std
# 72           3              142.0  mercedes-benz       gas        std
# 71          -1                NaN  mercedes-benz       gas        std
# 127          3                NaN        porsche       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 74           two      hardtop          rwd           front       112.0
# 16           two        sedan          rwd           front       103.5
# 73          four        sedan          rwd           front       120.9
# 128          two  convertible          rwd            rear        89.5
# 17          four        sedan          rwd           front       110.0
# 49           two        sedan          rwd           front       102.0
# 48          four        sedan          rwd           front       113.0
# 72           two  convertible          rwd           front        96.6
# 71          four        sedan          rwd           front       115.6
# 127          two      hardtop          rwd            rear        89.5
#
#       ...     engine-size  fuel-system  bore  stroke compression-ratio  \
# 74    ...             304         mpfi  3.80    3.35               8.0
# 16    ...             209         mpfi  3.62    3.39               8.0
# 73    ...             308         mpfi  3.80    3.35               8.0
# 128   ...             194         mpfi  3.74    2.90               9.5
# 17    ...             209         mpfi  3.62    3.39               8.0
# 49    ...             326         mpfi  3.54    2.76              11.5
# 48    ...             258         mpfi  3.63    4.17               8.1
# 72    ...             234         mpfi  3.46    3.10               8.3
# 71    ...             234         mpfi  3.46    3.10               8.3
# 127   ...             194         mpfi  3.74    2.90               9.5
#
#     horsepower  peak-rpm city-mpg  highway-mpg    price
# 74       184.0    4500.0       14           16  45400.0
# 16       182.0    5400.0       16           22  41315.0
# 73       184.0    4500.0       14           16  40960.0
# 128      207.0    5900.0       17           25  37028.0
# 17       182.0    5400.0       15           20  36880.0
# 49       262.0    5000.0       13           17  36000.0
# 48       176.0    4750.0       15           19  35550.0
# 72       155.0    4750.0       16           18  35056.0
# 71       155.0    4750.0       16           18  34184.0
# 127      207.0    5900.0       17           25  34028.0
#
# [10 rows x 26 columns]

# %%
data['make'].sort_values()
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
# 5             audi
# 6             audi
# 7             audi
# 8             audi
# 9             audi
# 17             bmw
# 16             bmw
# 15             bmw
# 14             bmw
# 12             bmw
# 11             bmw
# 10             bmw
# 13             bmw
# 18       chevrolet
# 19       chevrolet
# 20       chevrolet
# 27           dodge
# 29           dodge
# 28           dodge
# 26           dodge
# 23           dodge
# 24           dodge
# 22           dodge
# 21           dodge
# 25           dodge
#           ...
# 158         toyota
# 159         toyota
# 160         toyota
# 161         toyota
# 162         toyota
# 163         toyota
# 157         toyota
# 189     volkswagen
# 193     volkswagen
# 192     volkswagen
# 191     volkswagen
# 190     volkswagen
# 188     volkswagen
# 185     volkswagen
# 186     volkswagen
# 184     volkswagen
# 183     volkswagen
# 182     volkswagen
# 187     volkswagen
# 203          volvo
# 194          volvo
# 195          volvo
# 196          volvo
# 197          volvo
# 198          volvo
# 199          volvo
# 200          volvo
# 201          volvo
# 202          volvo
# 204          volvo
# Name: make, Length: 205, dtype: object

# %%
data['price'].head(2)
# Out:
# 0    13495.0
# 1    16500.0
# Name: price, dtype: float64

# %%
item_price_mod = data['price'].apply(lambda x : x + 1)
item_price_mod.head()
# Out:
# 0    13496.0
# 1    16501.0
# 2    16501.0
# 3    13951.0
# 4    17451.0
# Name: price, dtype: float64

# %%
### only works on series
data['drive-wheels'].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drive-wheels, dtype: int64

# %%
data['drive-wheels'].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           120
# rwd            76
# 4wd             9

# %%
drive_wheels_counts = data['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'}, inplace=True)
drive_wheels_counts
# Out:
#      value_counts
# fwd           120
# rwd            76
# 4wd             9

# %%
drive_wheels_counts.index.name = 'drive-wheels'
drive_wheels_counts
# Out:
#               value_counts
# drive-wheels
# fwd                    120
# rwd                     76
# 4wd                      9

# %% [markdown]
# ### Joins

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']})

df2 = pd.DataFrame({'D': ['D0', 'A5', 'A6', 'A7'],
                        'F': ['B4', 'B5', 'B6', 'B7'],
                        'G': ['C4', 'C5', 'C6', 'C7'],
                        'H': ['D4', 'D5', 'D6', 'D7']})               
result = pd.concat([df1, df2], axis=1, join='inner')
result

#pd.merge(df1,df2,on= 'D')
# Out:
#     A   B   C   D   D   F   G   H
# 0  A0  B0  C0  D0  D0  B4  C4  D4
# 1  A1  B1  C1  D1  A5  B5  C5  D5
# 2  A2  B2  C2  D2  A6  B6  C6  D6
# 3  A3  B3  C3  D3  A7  B7  C7  D7

# %%
#We can also use the ".idxmax()" method to calculate for us the most common type automatically:
data['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %% [markdown]
# ## Turning Categorical varible into Numerical Variables

# %% [markdown]
# 1.One Hot Encoding
# 2.Label encoder

# %% [markdown]
# We see the column "fuel-type" has two unique values, "gas" or "diesel".
# Regression doesn't understand words, only numbers.
# To use this attribute in regression analysis, we convert "fuel-type" into indicator variables.

# %%
data["fuel-type"].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
dummy_var_1 = pd.get_dummies(data["fuel-type"])
dummy_var_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
# merge data frame "df" and "dummy_variable_1" 
data = pd.concat([data, dummy_var_1], axis=1)
#data.head()
# drop original column "fuel-type" from "df"
data.drop("fuel-type", axis = 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-7f9ea1999107> in <module>()
#       3 #data.head()
#       4 # drop original column "fuel-type" from "df"
# ----> 5 data.drop("fuel-type", axis = 1, inplace=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3160                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    3161                 if errors == 'raise' and labels_missing:
# -> 3162                     raise KeyError('{} not found in axis'.format(labels))
#    3163
#    3164             slicer = [slice(None)] * self.ndim
#
# KeyError: "['fuel-type'] not found in axis"

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'diesel', 'gas'],
#       dtype='object')

# %% [markdown]
# <h3 id="pattern_visualization">1. Analyzing Individual Feature Patterns using Visualization</h3>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cor = data.corr()
cor
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.528667   -0.531954 -0.357612
# normalized-losses   0.528667           1.000000   -0.074362  0.023220
# wheel-base         -0.531954          -0.074362    1.000000  0.874587
# length             -0.357612           0.023220    0.874587  1.000000
# width              -0.232919           0.105073    0.795144  0.841118
# height             -0.541038          -0.432335    0.589435  0.491029
# curb-weight        -0.227691           0.119893    0.776386  0.877728
# engine-size        -0.105790           0.167365    0.569329  0.683360
# bore               -0.134205          -0.036167    0.490378  0.607480
# stroke             -0.008965           0.065627    0.161477  0.129739
# compression-ratio  -0.178515          -0.132654    0.249786  0.158414
# horsepower          0.071622           0.295772    0.352297  0.555003
# peak-rpm            0.274573           0.264597   -0.361052 -0.287325
# city-mpg           -0.035823          -0.258502   -0.470414 -0.670909
# highway-mpg         0.034606          -0.210768   -0.544082 -0.704662
# price              -0.082391           0.203254    0.584642  0.690628
# diesel             -0.194311          -0.116736    0.308346  0.212679
# gas                 0.194311           0.116736   -0.308346 -0.212679
# diesel             -0.194311          -0.116736    0.308346  0.212679
# gas                 0.194311           0.116736   -0.308346 -0.212679
# diesel             -0.194311          -0.116736    0.308346  0.212679
# gas                 0.194311           0.116736   -0.308346 -0.212679
# diesel             -0.194311          -0.116736    0.308346  0.212679
# gas                 0.194311           0.116736   -0.308346 -0.212679
#
#                       width    height  curb-weight  engine-size      bore  \
# symboling         -0.232919 -0.541038    -0.227691    -0.105790 -0.134205
# normalized-losses  0.105073 -0.432335     0.119893     0.167365 -0.036167
# wheel-base         0.795144  0.589435     0.776386     0.569329  0.490378
# length             0.841118  0.491029     0.877728     0.683360  0.607480
# width              1.000000  0.279210     0.867032     0.735433  0.559204
# height             0.279210  1.000000     0.295572     0.067149  0.176195
# curb-weight        0.867032  0.295572     1.000000     0.850594  0.649045
# engine-size        0.735433  0.067149     0.850594     1.000000  0.594090
# bore               0.559204  0.176195     0.649045     0.594090  1.000000
# stroke             0.182956 -0.056999     0.168929     0.206675 -0.055909
# compression-ratio  0.181129  0.261214     0.151362     0.028971  0.005203
# horsepower         0.642482 -0.110711     0.751034     0.810773  0.577273
# peak-rpm          -0.219957 -0.322272    -0.266306    -0.244618 -0.264269
# city-mpg          -0.642704 -0.048640    -0.757414    -0.653658 -0.594584
# highway-mpg       -0.677218 -0.107358    -0.797465    -0.677470 -0.594572
# price              0.751265  0.135486     0.834415     0.872335  0.543436
# diesel             0.233880  0.284631     0.217275     0.069594  0.054516
# gas               -0.233880 -0.284631    -0.217275    -0.069594 -0.054516
# diesel             0.233880  0.284631     0.217275     0.069594  0.054516
# gas               -0.233880 -0.284631    -0.217275    -0.069594 -0.054516
# diesel             0.233880  0.284631     0.217275     0.069594  0.054516
# gas               -0.233880 -0.284631    -0.217275    -0.069594 -0.054516
# diesel             0.233880  0.284631     0.217275     0.069594  0.054516
# gas               -0.233880 -0.284631    -0.217275    -0.069594 -0.054516
#
#                      stroke    ...     highway-mpg     price    diesel  \
# symboling         -0.008965    ...        0.034606 -0.082391 -0.194311
# normalized-losses  0.065627    ...       -0.210768  0.203254 -0.116736
# wheel-base         0.161477    ...       -0.544082  0.584642  0.308346
# length             0.129739    ...       -0.704662  0.690628  0.212679
# width              0.182956    ...       -0.677218  0.751265  0.233880
# height            -0.056999    ...       -0.107358  0.135486  0.284631
# curb-weight        0.168929    ...       -0.797465  0.834415  0.217275
# engine-size        0.206675    ...       -0.677470  0.872335  0.069594
# bore              -0.055909    ...       -0.594572  0.543436  0.054516
# stroke             1.000000    ...       -0.044528  0.082310  0.242081
# compression-ratio  0.186170    ...        0.265201  0.071107  0.984356
# horsepower         0.090254    ...       -0.770908  0.810533 -0.165278
# peak-rpm          -0.071493    ...       -0.054257 -0.101649 -0.477314
# city-mpg          -0.042906    ...        0.971337 -0.686571  0.255963
# highway-mpg       -0.044528    ...        1.000000 -0.704692  0.191392
# price              0.082310    ...       -0.704692  1.000000  0.110326
# diesel             0.242081    ...        0.191392  0.110326  1.000000
# gas               -0.242081    ...       -0.191392 -0.110326 -1.000000
# diesel             0.242081    ...        0.191392  0.110326  1.000000
# gas               -0.242081    ...       -0.191392 -0.110326 -1.000000
# diesel             0.242081    ...        0.191392  0.110326  1.000000
# gas               -0.242081    ...       -0.191392 -0.110326 -1.000000
# diesel             0.242081    ...        0.191392  0.110326  1.000000
# gas               -0.242081    ...       -0.191392 -0.110326 -1.000000
#
#                         gas    diesel       gas    diesel       gas    diesel  \
# symboling          0.194311 -0.194311  0.194311 -0.194311  0.194311 -0.194311
# normalized-losses  0.116736 -0.116736  0.116736 -0.116736  0.116736 -0.116736
# wheel-base        -0.308346  0.308346 -0.308346  0.308346 -0.308346  0.308346
# length            -0.212679  0.212679 -0.212679  0.212679 -0.212679  0.212679
# width             -0.233880  0.233880 -0.233880  0.233880 -0.233880  0.233880
# height            -0.284631  0.284631 -0.284631  0.284631 -0.284631  0.284631
# curb-weight       -0.217275  0.217275 -0.217275  0.217275 -0.217275  0.217275
# engine-size       -0.069594  0.069594 -0.069594  0.069594 -0.069594  0.069594
# bore              -0.054516  0.054516 -0.054516  0.054516 -0.054516  0.054516
# stroke            -0.242081  0.242081 -0.242081  0.242081 -0.242081  0.242081
# compression-ratio -0.984356  0.984356 -0.984356  0.984356 -0.984356  0.984356
# horsepower         0.165278 -0.165278  0.165278 -0.165278  0.165278 -0.165278
# peak-rpm           0.477314 -0.477314  0.477314 -0.477314  0.477314 -0.477314
# city-mpg          -0.255963  0.255963 -0.255963  0.255963 -0.255963  0.255963
# highway-mpg       -0.191392  0.191392 -0.191392  0.191392 -0.191392  0.191392
# price             -0.110326  0.110326 -0.110326  0.110326 -0.110326  0.110326
# diesel            -1.000000  1.000000 -1.000000  1.000000 -1.000000  1.000000
# gas                1.000000 -1.000000  1.000000 -1.000000  1.000000 -1.000000
# diesel            -1.000000  1.000000 -1.000000  1.000000 -1.000000  1.000000
# gas                1.000000 -1.000000  1.000000 -1.000000  1.000000 -1.000000
# diesel            -1.000000  1.000000 -1.000000  1.000000 -1.000000  1.000000
# gas                1.000000 -1.000000  1.000000 -1.000000  1.000000 -1.000000
# diesel            -1.000000  1.000000 -1.000000  1.000000 -1.000000  1.000000
# gas                1.000000 -1.000000  1.000000 -1.000000  1.000000 -1.000000
#
#                         gas
# symboling          0.194311
# normalized-losses  0.116736
# wheel-base        -0.308346
# length            -0.212679
# width             -0.233880
# height            -0.284631
# curb-weight       -0.217275
# engine-size       -0.069594
# bore              -0.054516
# stroke            -0.242081
# compression-ratio -0.984356
# horsepower         0.165278
# peak-rpm           0.477314
# city-mpg          -0.255963
# highway-mpg       -0.191392
# price             -0.110326
# diesel            -1.000000
# gas                1.000000
# diesel            -1.000000
# gas                1.000000
# diesel            -1.000000
# gas                1.000000
# diesel            -1.000000
# gas                1.000000
#
# [24 rows x 24 columns]

# %%
fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches

sns.heatmap(cor,xticklabels = cor.columns,yticklabels = cor.columns,annot = True,cmap = 'Blues_r',ax=ax)

# %% [markdown]
# <h3>Continuous numerical variables:</h3>

# %%
sns.distplot(data['wheel-base'],bins = 20)

# %%
data
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                NaN  alfa-romero        std          two
# 1            3                NaN  alfa-romero        std          two
# 2            1                NaN  alfa-romero        std          two
# 3            2              164.0         audi        std         four
# 4            2              164.0         audi        std         four
# 5            2                NaN         audi        std          two
# 6            1              158.0         audi        std         four
# 7            1                NaN         audi        std         four
# 8            1              158.0         audi      turbo         four
# 9            0                NaN         audi      turbo          two
# 10           2              192.0          bmw        std          two
# 11           0              192.0          bmw        std         four
# 12           0              188.0          bmw        std          two
# 13           0              188.0          bmw        std         four
# 14           1                NaN          bmw        std         four
# 15           0                NaN          bmw        std         four
# 16           0                NaN          bmw        std          two
# 17           0                NaN          bmw        std         four
# 18           2              121.0    chevrolet        std          two
# 19           1               98.0    chevrolet        std          two
# 20           0               81.0    chevrolet        std         four
# 21           1              118.0        dodge        std          two
# 22           1              118.0        dodge        std          two
# 23           1              118.0        dodge      turbo          two
# 24           1              148.0        dodge        std         four
# 25           1              148.0        dodge        std         four
# 26           1              148.0        dodge        std         four
# 27           1              148.0        dodge      turbo          NaN
# 28          -1              110.0        dodge        std         four
# 29           3              145.0        dodge      turbo          two
# ..         ...                ...          ...        ...          ...
# 175         -1               65.0       toyota        std         four
# 176         -1               65.0       toyota        std         four
# 177         -1               65.0       toyota        std         four
# 178          3              197.0       toyota        std          two
# 179          3              197.0       toyota        std          two
# 180         -1               90.0       toyota        std         four
# 181         -1                NaN       toyota        std         four
# 182          2              122.0   volkswagen        std          two
# 183          2              122.0   volkswagen        std          two
# 184          2               94.0   volkswagen        std         four
# 185          2               94.0   volkswagen        std         four
# 186          2               94.0   volkswagen        std         four
# 187          2               94.0   volkswagen      turbo         four
# 188          2               94.0   volkswagen        std         four
# 189          3                NaN   volkswagen        std          two
# 190          3              256.0   volkswagen        std          two
# 191          0                NaN   volkswagen        std         four
# 192          0                NaN   volkswagen      turbo         four
# 193          0                NaN   volkswagen        std         four
# 194         -2              103.0        volvo        std         four
# 195         -1               74.0        volvo        std         four
# 196         -2              103.0        volvo        std         four
# 197         -1               74.0        volvo        std         four
# 198         -2              103.0        volvo      turbo         four
# 199         -1               74.0        volvo      turbo         four
# 200         -1               95.0        volvo        std         four
# 201         -1               95.0        volvo      turbo         four
# 202         -1               95.0        volvo        std         four
# 203         -1               95.0        volvo      turbo         four
# 204         -1               95.0        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  length ...   \
# 0    convertible          rwd           front        88.6   168.8 ...
# 1    convertible          rwd           front        88.6   168.8 ...
# 2      hatchback          rwd           front        94.5   171.2 ...
# 3          sedan          fwd           front        99.8   176.6 ...
# 4          sedan          4wd           front        99.4   176.6 ...
# 5          sedan          fwd           front        99.8   177.3 ...
# 6          sedan          fwd           front       105.8   192.7 ...
# 7          wagon          fwd           front       105.8   192.7 ...
# 8          sedan          fwd           front       105.8   192.7 ...
# 9      hatchback          4wd           front        99.5   178.2 ...
# 10         sedan          rwd           front       101.2   176.8 ...
# 11         sedan          rwd           front       101.2   176.8 ...
# 12         sedan          rwd           front       101.2   176.8 ...
# 13         sedan          rwd           front       101.2   176.8 ...
# 14         sedan          rwd           front       103.5   189.0 ...
# 15         sedan          rwd           front       103.5   189.0 ...
# 16         sedan          rwd           front       103.5   193.8 ...
# 17         sedan          rwd           front       110.0   197.0 ...
# 18     hatchback          fwd           front        88.4   141.1 ...
# 19     hatchback          fwd           front        94.5   155.9 ...
# 20         sedan          fwd           front        94.5   158.8 ...
# 21     hatchback          fwd           front        93.7   157.3 ...
# 22     hatchback          fwd           front        93.7   157.3 ...
# 23     hatchback          fwd           front        93.7   157.3 ...
# 24     hatchback          fwd           front        93.7   157.3 ...
# 25         sedan          fwd           front        93.7   157.3 ...
# 26         sedan          fwd           front        93.7   157.3 ...
# 27         sedan          fwd           front        93.7   157.3 ...
# 28         wagon          fwd           front       103.3   174.6 ...
# 29     hatchback          fwd           front        95.9   173.2 ...
# ..           ...          ...             ...         ...     ... ...
# 175    hatchback          fwd           front       102.4   175.6 ...
# 176        sedan          fwd           front       102.4   175.6 ...
# 177    hatchback          fwd           front       102.4   175.6 ...
# 178    hatchback          rwd           front       102.9   183.5 ...
# 179    hatchback          rwd           front       102.9   183.5 ...
# 180        sedan          rwd           front       104.5   187.8 ...
# 181        wagon          rwd           front       104.5   187.8 ...
# 182        sedan          fwd           front        97.3   171.7 ...
# 183        sedan          fwd           front        97.3   171.7 ...
# 184        sedan          fwd           front        97.3   171.7 ...
# 185        sedan          fwd           front        97.3   171.7 ...
# 186        sedan          fwd           front        97.3   171.7 ...
# 187        sedan          fwd           front        97.3   171.7 ...
# 188        sedan          fwd           front        97.3   171.7 ...
# 189  convertible          fwd           front        94.5   159.3 ...
# 190    hatchback          fwd           front        94.5   165.7 ...
# 191        sedan          fwd           front       100.4   180.2 ...
# 192        sedan          fwd           front       100.4   180.2 ...
# 193        wagon          fwd           front       100.4   183.1 ...
# 194        sedan          rwd           front       104.3   188.8 ...
# 195        wagon          rwd           front       104.3   188.8 ...
# 196        sedan          rwd           front       104.3   188.8 ...
# 197        wagon          rwd           front       104.3   188.8 ...
# 198        sedan          rwd           front       104.3   188.8 ...
# 199        wagon          rwd           front       104.3   188.8 ...
# 200        sedan          rwd           front       109.1   188.8 ...
# 201        sedan          rwd           front       109.1   188.8 ...
# 202        sedan          rwd           front       109.1   188.8 ...
# 203        sedan          rwd           front       109.1   188.8 ...
# 204        sedan          rwd           front       109.1   188.8 ...
#
#      highway-mpg    price  diesel  gas  diesel  gas  diesel  gas  diesel  gas
# 0             27  13495.0       0    1       0    1       0    1       0    1
# 1             27  16500.0       0    1       0    1       0    1       0    1
# 2             26  16500.0       0    1       0    1       0    1       0    1
# 3             30  13950.0       0    1       0    1       0    1       0    1
# 4             22  17450.0       0    1       0    1       0    1       0    1
# 5             25  15250.0       0    1       0    1       0    1       0    1
# 6             25  17710.0       0    1       0    1       0    1       0    1
# 7             25  18920.0       0    1       0    1       0    1       0    1
# 8             20  23875.0       0    1       0    1       0    1       0    1
# 9             22      NaN       0    1       0    1       0    1       0    1
# 10            29  16430.0       0    1       0    1       0    1       0    1
# 11            29  16925.0       0    1       0    1       0    1       0    1
# 12            28  20970.0       0    1       0    1       0    1       0    1
# 13            28  21105.0       0    1       0    1       0    1       0    1
# 14            25  24565.0       0    1       0    1       0    1       0    1
# 15            22  30760.0       0    1       0    1       0    1       0    1
# 16            22  41315.0       0    1       0    1       0    1       0    1
# 17            20  36880.0       0    1       0    1       0    1       0    1
# 18            53   5151.0       0    1       0    1       0    1       0    1
# 19            43   6295.0       0    1       0    1       0    1       0    1
# 20            43   6575.0       0    1       0    1       0    1       0    1
# 21            41   5572.0       0    1       0    1       0    1       0    1
# 22            38   6377.0       0    1       0    1       0    1       0    1
# 23            30   7957.0       0    1       0    1       0    1       0    1
# 24            38   6229.0       0    1       0    1       0    1       0    1
# 25            38   6692.0       0    1       0    1       0    1       0    1
# 26            38   7609.0       0    1       0    1       0    1       0    1
# 27            30   8558.0       0    1       0    1       0    1       0    1
# 28            30   8921.0       0    1       0    1       0    1       0    1
# 29            24  12964.0       0    1       0    1       0    1       0    1
# ..           ...      ...     ...  ...     ...  ...     ...  ...     ...  ...
# 175           32   9988.0       0    1       0    1       0    1       0    1
# 176           32  10898.0       0    1       0    1       0    1       0    1
# 177           32  11248.0       0    1       0    1       0    1       0    1
# 178           24  16558.0       0    1       0    1       0    1       0    1
# 179           24  15998.0       0    1       0    1       0    1       0    1
# 180           24  15690.0       0    1       0    1       0    1       0    1
# 181           24  15750.0       0    1       0    1       0    1       0    1
# 182           46   7775.0       1    0       1    0       1    0       1    0
# 183           34   7975.0       0    1       0    1       0    1       0    1
# 184           46   7995.0       1    0       1    0       1    0       1    0
# 185           34   8195.0       0    1       0    1       0    1       0    1
# 186           34   8495.0       0    1       0    1       0    1       0    1
# 187           42   9495.0       1    0       1    0       1    0       1    0
# 188           32   9995.0       0    1       0    1       0    1       0    1
# 189           29  11595.0       0    1       0    1       0    1       0    1
# 190           29   9980.0       0    1       0    1       0    1       0    1
# 191           24  13295.0       0    1       0    1       0    1       0    1
# 192           38  13845.0       1    0       1    0       1    0       1    0
# 193           31  12290.0       0    1       0    1       0    1       0    1
# 194           28  12940.0       0    1       0    1       0    1       0    1
# 195           28  13415.0       0    1       0    1       0    1       0    1
# 196           28  15985.0       0    1       0    1       0    1       0    1
# 197           28  16515.0       0    1       0    1       0    1       0    1
# 198           22  18420.0       0    1       0    1       0    1       0    1
# 199           22  18950.0       0    1       0    1       0    1       0    1
# 200           28  16845.0       0    1       0    1       0    1       0    1
# 201           25  19045.0       0    1       0    1       0    1       0    1
# 202           23  21485.0       0    1       0    1       0    1       0    1
# 203           27  22470.0       1    0       1    0       1    0       1    0
# 204           25  22625.0       0    1       0    1       0    1       0    1
#
# [205 rows x 33 columns]

# %%
sns.relplot(x="engine-size", y="price", data=data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-de2c2a526b75> in <module>()
# ----> 1 sns.relplot(x="engine-size", y="price", data=data)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1574         sizes=sizes, size_order=size_order, size_norm=size_norm,
#    1575         markers=markers, dashes=dashes, style_order=style_order,
# -> 1576         legend=legend,
#    1577     )
#    1578
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     850
#     851         plot_data = self.establish_variables(
# --> 852             x, y, hue, size, style, units, data
#     853         )
#     854
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     131                 x = data.get(x, x)
#     132                 y = data.get(y, y)
# --> 133                 hue = data.get(hue, hue)
#     134                 size = data.get(size, size)
#     135                 style = data.get(style, style)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in get(self, key, default)
#    2475         """
#    2476         try:
# -> 2477             return self[key]
#    2478         except (KeyError, ValueError, IndexError):
#    2479             return default
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
# -> 2698         result = self._constructor(self._data.get(key))
#    2699         if result.columns.is_unique:
#    2700             result = result[key]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4128
#    4129             if isna(item):
# -> 4130                 raise TypeError("cannot label index with a null key")
#    4131
#    4132             indexer = self.items.get_indexer_for([item])
#
# TypeError: cannot label index with a null key

# %%
# Engine size as potential predictor variable of price
sns.regplot(x="engine-size", y="price", data=data)
plt.ylim(0,)
# Out:
# (0, 55949.658212258946)

# %% [markdown]
# <b>Correlation</b>
# <p><b>Correlation</b>: a term that is a measure of the strength of a linear relationship between two quantitative variables.</p>

# %% [markdown]
# #### Check for Corelation

# %%
data[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
sns.regplot(x="highway-mpg", y="price", data=data)

# %% [markdown]
# #### Check for Corelation

# %%
data[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
sns.regplot(x="peak-rpm", y="price", data=data)

# %%
data[['peak-rpm', 'price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101649
# price    -0.101649  1.000000

# %% [markdown]
# <h3>Categorical variables</h3>

# %% [markdown]
# <html>
# <a href ='https://datavizcatalogue.com/methods/images/anatomy/box_plot.png '>Box Plot</a>

# %%
sns.boxplot(x="body-style", y="price", data=data)

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price', 'diesel',
#        'gas'],
#       dtype='object')

# %% [markdown]
# <h2 id="basic_grouping">Basics of Grouping</h2>

# %%
data['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %% [markdown]
# #### we want to know, on average, which type of drive wheel is most valuable?

# %%
df_group_one = data[['drive-wheels','body-style','price']]
df_group_one
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# 5            fwd        sedan  15250.0
# 6            fwd        sedan  17710.0
# 7            fwd        wagon  18920.0
# 8            fwd        sedan  23875.0
# 9            4wd    hatchback      NaN
# 10           rwd        sedan  16430.0
# 11           rwd        sedan  16925.0
# 12           rwd        sedan  20970.0
# 13           rwd        sedan  21105.0
# 14           rwd        sedan  24565.0
# 15           rwd        sedan  30760.0
# 16           rwd        sedan  41315.0
# 17           rwd        sedan  36880.0
# 18           fwd    hatchback   5151.0
# 19           fwd    hatchback   6295.0
# 20           fwd        sedan   6575.0
# 21           fwd    hatchback   5572.0
# 22           fwd    hatchback   6377.0
# 23           fwd    hatchback   7957.0
# 24           fwd    hatchback   6229.0
# 25           fwd        sedan   6692.0
# 26           fwd        sedan   7609.0
# 27           fwd        sedan   8558.0
# 28           fwd        wagon   8921.0
# 29           fwd    hatchback  12964.0
# ..           ...          ...      ...
# 175          fwd    hatchback   9988.0
# 176          fwd        sedan  10898.0
# 177          fwd    hatchback  11248.0
# 178          rwd    hatchback  16558.0
# 179          rwd    hatchback  15998.0
# 180          rwd        sedan  15690.0
# 181          rwd        wagon  15750.0
# 182          fwd        sedan   7775.0
# 183          fwd        sedan   7975.0
# 184          fwd        sedan   7995.0
# 185          fwd        sedan   8195.0
# 186          fwd        sedan   8495.0
# 187          fwd        sedan   9495.0
# 188          fwd        sedan   9995.0
# 189          fwd  convertible  11595.0
# 190          fwd    hatchback   9980.0
# 191          fwd        sedan  13295.0
# 192          fwd        sedan  13845.0
# 193          fwd        wagon  12290.0
# 194          rwd        sedan  12940.0
# 195          rwd        wagon  13415.0
# 196          rwd        sedan  15985.0
# 197          rwd        wagon  16515.0
# 198          rwd        sedan  18420.0
# 199          rwd        wagon  18950.0
# 200          rwd        sedan  16845.0
# 201          rwd        sedan  19045.0
# 202          rwd        sedan  21485.0
# 203          rwd        sedan  22470.0
# 204          rwd        sedan  22625.0
#
# [205 rows x 3 columns]

# %%
# grouping results
df_group_one = df_group_one.groupby(['drive-wheels'],as_index=False).mean()
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
# multiple variables/labels grouping
df_gptest = data[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# #### Reference Links

# %% [markdown]
# <html>
# <a href =https://pandas.pydata.org/pandas-docs/version/0.15/dsintro.html >Pandas Documentation</a>
